# %%
import numpy as np
import folium
import pandas as pd
from folium import plugins
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
from folium.plugins import MarkerCluster
import json
import warnings
warnings.filterwarnings('ignore')

# %%
pd.read_csv('./data/14.세종시_상권정보.csv')
# Out:
#       상권업종대분류코드  상권업종대분류명 상권업종중분류코드      상권업종중분류명 상권업종소분류코드     상권업종소분류명  \
# 0             D        소매       D21  철물/난방/건설자재소매    D21A06    철물/건설자재소매
# 1             D        소매       D21  철물/난방/건설자재소매    D21A02    보일러/냉난방용품
# 2             F     생활서비스       F15          주택수리    F15A03      배관난방보일러
# 3             Q        음식       Q04            분식    Q04A01       라면김밥분식
# 4             D        소매       D11          유아용품    D11A03       유아용품판매
# ...         ...       ...       ...           ...       ...          ...
# 10768         D        소매       D23     자동차/자동차용품    D23A04        타이어판매
# 10769         L       부동산       L01         부동산중개    L01A01        부동산중개
# 10770         Q        음식       Q06            양식    Q06A02       돈가스전문점
# 10771         N  관광/여가/오락       N02      무도/유흥/가무    N02A01          노래방
# 10772         R     학문/교육       R05     학원-음악미술무용    R05A02  피아노/바이올린/기타
#
#       표준산업분류코드              표준산업분류명       행정동코드  행정동명  \
# ...

# %%
df = pd.read_csv('./data/3.세종시_아파트(매매)_실거래가.csv', encoding='cp949' )
df
# Out:
#          계약년월  계약일               시군구    본번  부번                단지명   전용면적(㎡)  \
# 0      201701    1       세종특별자치시 보람동   628   2       스타힐타워Ⅰ(C2-3)   16.9849
# 1      201701    1       세종특별자치시 종촌동   683   0  가재마을2단지(호반베르디움3차)   59.8652
# 2      201701    2       세종특별자치시 고운동  1393   0    가락마을15단지(중흥파크뷰)   84.9894
# 3      201701    2       세종특별자치시 고운동  1706   0    가락마을8단지(고운뜰아파트)   84.9800
# 4      201701    2       세종특별자치시 아름동  1284   0    범지기마을7단지 호반에코시티   84.9280
# ...       ...  ...               ...   ...  ..                ...       ...
# 21135  202010   27  세종특별자치시 조치원읍 신흥리   399   0    조치원 신흥 e편한세상(아)  176.3430
# 21136  202010   27  세종특별자치시 조치원읍 침산리    89   0              욱일아파트   84.9900
# 21137  202010   28       세종특별자치시 도담동   639   0    도램마을17단지(모아미래도)   84.9690
# 21138  202010   28   세종특별자치시 부강면 부강리   401  48                 주연   59.8200
# 21139  202010   28  세종특별자치시 조치원읍 죽림리   396   0            조치원죽림자이   84.6641
#
#        거래금액(만원)   층  건축년도
# 0          8600   7  2016
# ...

# %%
df.groupby('시군구')['시군구'].count()
# Out:
# 시군구
# 세종특별자치시 고운동         2454
# 세종특별자치시 금남면 용포리      541
# 세종특별자치시 나성동          346
# 세종특별자치시 다정동          750
# 세종특별자치시 대평동          244
# 세종특별자치시 도담동         2223
# 세종특별자치시 반곡동          169
# 세종특별자치시 보람동          683
# 세종특별자치시 부강면 부강리      112
# 세종특별자치시 새롬동         1150
# 세종특별자치시 소담동          968
# 세종특별자치시 소정면 운당리       29
# 세종특별자치시 아름동         2538
# 세종특별자치시 어진동          409
# 세종특별자치시 연동면 명학리      168
# 세종특별자치시 연서면 봉암리      123
# 세종특별자치시 장군면 금암리       70
# 세종특별자치시 전동면 노장리       21
# 세종특별자치시 전의면 동교리       64
# 세종특별자치시 전의면 유천리       36
# 세종특별자치시 조치원읍 교리      103
# 세종특별자치시 조치원읍 남리      119
# 세종특별자치시 조치원읍 번암리     204
# 세종특별자치시 조치원읍 서창리      27
# 세종특별자치시 조치원읍 신안리     679
# 세종특별자치시 조치원읍 신흥리     778
# 세종특별자치시 조치원읍 원리       19
# 세종특별자치시 조치원읍 정리       10
# 세종특별자치시 조치원읍 죽림리    1146
# 세종특별자치시 조치원읍 침산리     372
# 세종특별자치시 종촌동         2746
# 세종특별자치시 한솔동         1839
# Name: 시군구, dtype: int64

# %%
df = pd.read_csv('./data/14.세종시_상권정보.csv')
df
# Out:
#       상권업종대분류코드  상권업종대분류명 상권업종중분류코드      상권업종중분류명 상권업종소분류코드     상권업종소분류명  \
# 0             D        소매       D21  철물/난방/건설자재소매    D21A06    철물/건설자재소매
# 1             D        소매       D21  철물/난방/건설자재소매    D21A02    보일러/냉난방용품
# 2             F     생활서비스       F15          주택수리    F15A03      배관난방보일러
# 3             Q        음식       Q04            분식    Q04A01       라면김밥분식
# 4             D        소매       D11          유아용품    D11A03       유아용품판매
# ...         ...       ...       ...           ...       ...          ...
# 10768         D        소매       D23     자동차/자동차용품    D23A04        타이어판매
# 10769         L       부동산       L01         부동산중개    L01A01        부동산중개
# 10770         Q        음식       Q06            양식    Q06A02       돈가스전문점
# 10771         N  관광/여가/오락       N02      무도/유흥/가무    N02A01          노래방
# 10772         R     학문/교육       R05     학원-음악미술무용    R05A02  피아노/바이올린/기타
#
#       표준산업분류코드              표준산업분류명       행정동코드  행정동명  \
# ...

# %%
df.groupby('행정동명')['행정동명'].count().tail(60)
# Out:
# 행정동명
# 고운동      353
# 금남면      699
# 대평동      111
# 도담동      803
# 보람동      420
# 부강면      436
# 새롬동     1118
# 소담동      212
# 소정면      165
# 아름동      277
# 연기면      194
# 연동면      156
# 연서면      444
# 장군면      465
# 전동면      143
# 전의면      417
# 조치원읍    3553
# 종촌동      346
# 한솔동      461
# Name: 행정동명, dtype: int64

# %%
df

# %%
df = gpd.read_file('./data/30.세종시_법정경계(시군구).geojson') # 경계선 만들기위한 자료
df

# %%
df = pd.read_csv('./data/28.세종시_지역별_세대원수별_세대수.csv', encoding='cp949' )
df
# Out:
#       읍면동      계    1인    2인    3인    4인    5인   6인  7인  8인  9인  10인이상
# 0    조치원읍  19472  8295  4165  3042  2729   944  220  63   9   4      1
# 1   연 기 면   1445   855   299   133   101    36   11   7   1   2      0
# 2   연 동 면   1680   834   461   206   114    44   14   5   1   0      1
# 3   부 강 면   3249  1603   821   420   273    93   34   3   0   0      2
# 4   금 남 면   4509  2128  1283   589   328   122   41  12   6   0      0
# 5   장 군 면   3453  1956   806   332   200   106   35  11   6   1      0
# 6   연 서 면   3834  1863  1022   484   276   129   38  16   3   2      1
# 7   전 의 면   3045  1551   753   352   244   107   29   8   0   1      0
# 8   전 동 면   2130  1224   491   213   124    57   15   6   0   0      0
# 9   소 정 면   1231   565   308   160   127    58    9   1   2   1      0
# 10  한 솔 동   6333  1069  1134  1468  1944   584  101  25   5   1      2
# 11  새 롬 동  20495  6019  3980  4283  4754  1201  201  39  12   4      2
# ...

# %%
df = pd.read_csv('./data/27.세종시_월평균_가구소득.csv', encoding='cp949' )
df
# Out:
#         중분류          소분류 100만원 미만  100~200만원 미만  200~300만원 미만  300~400만원 미만  \
# 0        전체           소계     10.9          11.0          14.6          17.8
# 1    읍·면·동별         조치원읍     25.7          18.6          16.6          13.3
# 2    읍·면·동별          면지역     22.7          21.0          21.2          16.7
# 3    읍·면·동별          동지역      2.6           5.4          11.8          19.4
# 4        성별           남자      7.3           8.5          13.6          19.3
# 5        성별           여자     21.8          18.5          17.6          13.2
# 6     거주기간별         출범이전     22.7          18.9          15.0          16.8
# 7     거주기간별         출범이후      6.2           7.8          14.4          18.1
# 8       연령별       13~19세     79.6          20.4           0.0           0.0
# 9       연령별       20~29세     24.9          22.0          31.9          10.6
# 10      연령별       30~39세      1.4           2.5          15.0          27.2
# ...
